# %%
from quantum_logical.pulsesim.module_build_1 import Module_build, Create_plots
import matplotlib.pyplot as plt

# %%
store_fids = []
lam_power = []
fig, ax = plt.subplots()
for j in range(1,6):
    for i in range(2,7):
        a = Module_build(dim = 2, lam_power = i, mod_count = j, lam_mag=.1)
        store_fids.append(a.results())
        lam_power.append(i)

    # b = Create_plots(x = lam_power, y = store_fids, num_module = j)
    # b.plot_create()
    ax.plot(lam_power, store_fids, marker='o', linestyle = '-', label = "%s" %(j))

    store_fids.clear()
    lam_power.clear()
fig.legend(loc = 'center right')
ax.set_yscale('log')
fig.show()
# Out:
# C:\Users\girgi\Desktop\Github\quantum_logical\src\quantum_logical\pulsesim\module_build_1.py:140: RuntimeWarning: divide by zero encountered in scalar divide
#   a = ((np.exp(-1j*(w1-w2-wp)*t))/(-1j*(w1-w2-wp)) - (1/(-1j*(w1-w2-wp))))
# C:\Users\girgi\Desktop\Github\quantum_logical\src\quantum_logical\pulsesim\module_build_1.py:140: RuntimeWarning: invalid value encountered in scalar divide
#   a = ((np.exp(-1j*(w1-w2-wp)*t))/(-1j*(w1-w2-wp)) - (1/(-1j*(w1-w2-wp))))
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 6
#       4 for j in range(1,6):
#       5     for i in range(2,7):
# ----> 6         a = Module_build(dim = 2, lam_power = i, mod_count = j, lam_mag=.1)
#       7         store_fids.append(a.results())
#       8         lam_power.append(i)
#
# File ~\Desktop\Github\quantum_logical\src\quantum_logical\pulsesim\module_build_1.py:156, in Module_build.__init__(self, dim, lam_power, mod_count, lam_mag)
#     154 qubit1_adj_qubit2_val = int_func_conj_wp_conj(w1,w2,wp,T)
#     155 qubit1_qubit3_adj_val = int_func(w1,w3,wp,T) + int_func_conj_wp(w1,w3,wp,T)
# --> 156 qubit2_qubit3_adj_val = int_func(w2,w3,wp,T) + int_func_conj_wp(w2,w3,wp,T)
#     157 qubit1_adj_qubit3_val = int_func(w3,w1,wp,T) + int_func_conj_wp(w3,w1,wp,T)
#     158 qubit2_adj_qubit3_val = int_func(w3,w2,wp,T) + int_func_conj_wp(w3,w2,wp,T)
#
# File ~\Desktop\Github\quantum_logical\src\quantum_logical\pulsesim\module_build_1.py:140, in Module_build.__init__.<locals>.int_func_conj_wp(w1, w2, wp, t)
#     139 def int_func_conj_wp(w1,w2,wp,t):
# --> 140     a = ((np.exp(-1j*(w1-w2-wp)*t))/(-1j*(w1-w2-wp)) - (1/(-1j*(w1-w2-wp))))
#     141     return a
#
# ZeroDivisionError: complex division by zero

# %%
a = Module_build(dim = 2, lam_power = 2, mod_count = 1)
a.results()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a = Module_build(dim = 2, lam_power = 2, mod_count = 1)
#       2 a.results()
#
# File ~\Desktop\Github\quantum_logical\src\quantum_logical\pulsesim\module_build.py:222, in Module_build.__init__(self, dim, lam_power, mod_count)
#     217         H_tot.append(H_total[12])
#     219     return [H_tot, ts]
# --> 222 res = mod_amount(self.word)
#     224 # extract out the hamiltonian and the time multiplier from the mod count results
#     225 multiplier_times = res[1]
#
# File ~\Desktop\Github\quantum_logical\src\quantum_logical\pulsesim\module_build.py:209, in Module_build.__init__.<locals>.mod_amount(count)
#     207 ts = []
#     208 for i in range(len(H_total) - len(H_addition)):
# --> 209     ts.append(T_mult[i])
#     210     H_tot.append(H_total[i])
#     211     # this is how I have added in the original portions of the hamiltonian
#     212 # now you have to add the other parts of the hamiltonian
#
# IndexError: list index out of range

# %%
a = []
x = []
for i in range(5):
    b = Module_build(dim = 2, lam_power = 4, mod_count = i)
    a.append(b.results())
    x.append(i)

plt.plot(x, a, marker = ".")
plt.xticks(x)
plt.xlabel("Module count")
plt.ylabel("Fidelity")
plt.title(f"Fidelity vs Module count for $λ^{4}$")

plt.savefig("lam_4_plot.svg")
